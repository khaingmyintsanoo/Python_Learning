# %%
from PIL import Image

# %%
mac = Image.open('1.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f065245980e2> in <module>
# ----> 1 mac = Image.open('1.jpg')
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: '1.jpg'

# %%
mac = Image.open('1.png')

# %%
type(mac)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=623x567 at 0x1C6DF02F108>

# %%
mac.show()

# %%
mac.size
# Out:
# (623, 567)

# %%
mac.filename
# Out:
# '1.png'

# %%
mac.format_description
# Out:
# 'Portable network graphics'

# %%
mac.crop()
# Out:
# <PIL.Image.Image image mode=RGBA size=623x567 at 0x1C6DF0CEE88>

# %%
mac.crop(0,0,100,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-546ce35dbd23> in <module>
# ----> 1 mac.crop(0,0,100,100)
#
# TypeError: crop() takes from 1 to 2 positional arguments but 5 were given

# %%
mac.crop((0,0,50,50))
# Out:
# <PIL.Image.Image image mode=RGBA size=50x50 at 0x1C6DF0DB048>

# %%
example = Image.open('example.jpg')

# %%
example
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x1C6DF0DB6C8>

# %%
example.size
# Out:
# (300, 168)

# %%
x=0
y=0
w=300/3
h=168/10

# %%
example.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=100x17 at 0x1C6DF0CED88>

# %%
mac.size
# Out:
# (623, 567)

# %%
halfway = 623/3

# %%
x=halfway -200
w=halfway + 200

# %%
y=800
h=567

# %%
mac.crop((x,y,w,h))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     898         chunk(fp, b"eXIf", exif)
#     899
# --> 900     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#     901
#     902     chunk(fp, b"IEND", b"")
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     502             if o > 0:
#     503                 fp.seek(o)
# --> 504             e.setimage(im.im, b)
#     505             if e.pushes_fd:
#     506                 e.setfd(fp)
#
# SystemError: tile cannot extend outside image
# <PIL.Image.Image image mode=RGBA size=400x0 at 0x1C6DF0E4208>

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=623x567 at 0x1C6DF02F108>

# %%
mac.size
# Out:
# (623, 567)

# %%
hlafway=623/2

# %%
x = halfway - 200
w = halfway + 200

# %%
y= 300
h = 567

# %%
mac.crop((x,y,w,h))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     898         chunk(fp, b"eXIf", exif)
#     899
# --> 900     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#     901
#     902     chunk(fp, b"IEND", b"")
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     502             if o > 0:
#     503                 fp.seek(o)
# --> 504             e.setimage(im.im, b)
#     505             if e.pushes_fd:
#     506                 e.setfd(fp)
#
# SystemError: tile cannot extend outside image
# <PIL.Image.Image image mode=RGBA size=400x0 at 0x1C6DF0CE9C8>

# %%
red = Image.open('red.png')

# %%
red
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=219x123 at 0x1C6DF0CCF88>

# %%
blue = Image.open('blue.png')

# %%
blue.putalpha(255)

# %%
blue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     790     try:
# --> 791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
#
# KeyError: 'PA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
# --> 793         raise OSError("cannot write mode %s as PNG" % mode)
#     794
#     795     #
#
# OSError: cannot write mode PA as PNG
# <PIL.PngImagePlugin.PngImageFile image mode=PA size=290x174 at 0x1C6DF11FD08>

# %%
blue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     790     try:
# --> 791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
#
# KeyError: 'PA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
# --> 793         raise OSError("cannot write mode %s as PNG" % mode)
#     794
#     795     #
#
# OSError: cannot write mode PA as PNG
# <PIL.PngImagePlugin.PngImageFile image mode=PA size=290x174 at 0x1C6DF11FD08>

# %%
blue = Image.open('blue.png')

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=290x174 at 0x1C6DF12AF48>

# %%
blue.putalpha(255)

# %%
blue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     790     try:
# --> 791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
#
# KeyError: 'PA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
# --> 793         raise OSError("cannot write mode %s as PNG" % mode)
#     794
#     795     #
#
# OSError: cannot write mode PA as PNG
# <PIL.PngImagePlugin.PngImageFile image mode=PA size=290x174 at 0x1C6DF12AF48>

# %%
red.putalpha(128)

# %%
red
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     790     try:
# --> 791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
#
# KeyError: 'PA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     791         rawmode, mode = _OUTMODES[mode]
#     792     except KeyError:
# --> 793         raise OSError("cannot write mode %s as PNG" % mode)
#     794
#     795     #
#
# OSError: cannot write mode PA as PNG
# <PIL.PngImagePlugin.PngImageFile image mode=PA size=219x123 at 0x1C6DF0CCF88>

# %%
blue.paste(im=red,box=(0,0),mask=red)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-92f914756e73> in <module>
# ----> 1 blue.paste(im=red,box=(0,0),mask=red)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in paste(self, im, box, mask)
#    1464         if mask:
#    1465             mask.load()
# -> 1466             self.im.paste(im, box, mask.im)
#    1467         else:
#    1468             self.im.paste(im, box)
#
# ValueError: bad transparency mask
