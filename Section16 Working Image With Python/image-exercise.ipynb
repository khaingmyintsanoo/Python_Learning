# %%
from = PIL import image
# Out:
#   File "<ipython-input-1-675a371c7203>", line 1
#     from = PIL import image
#          ^
# SyntaxError: invalid syntax

# %%
from PIL import Image

# %%
words=Image.open('example.jpg')

# %%
mask =Image.open('1.png')

# %%
words
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x20F08299CC8>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=623x567 at 0x20F083233C8>

# %%
words.paste(mask,(0,0),mask)

# %%
words.size
# Out:
# (300, 168)

# %%
mask=mask.resize((300,168))

# %%
mask.size
# Out:
# (300, 168)

# %%
mask.putalpha(200)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=300x168 at 0x20F0821D748>

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x20F08299CC8>
